# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
import sys
from scipy.integrate import odeint
from scipy.integrate import solve_ivp

# %%
#vedio
def function1():

# wourld wide average carbon generation by unit power

    p1=np.array([820,702,490,12,24,230,11,12,48,38,27])   #g Co2/kW
    p2=np.array([0.38106531, 0.03041596, 0.23030303, 0.10231508, 0.1582157 ,
           0.02394128, 0.04509693, 0.00252212, 0.02228496, 0.00338792,
           0.00045172])
    p_c=np.sum(p1*p2)


    #client - Desktop

    p_notebook= 30 # W
    #client - Desktop
    p_desktop=150 #W
    
    # phone
    p_mobile=10 # W

    # home network  bandwidth

    b_net=16 # GB/hour

    #total_gCO2e = data_utilsation*(data_centre_electricity usage +transmission_electricity usage)*gCO2e_for_electricity_generation

    # electricity consumption during operation , three parts:servers, clients, routers, per hour

    es_ser=  0.01*p_c     #  kW/GB*g/kW=g/GB
    es_cli=  p_desktop*1/1000/(b_net)*p_c        #kW/h*1hour/GB in one hour * g/GB =g/GB
    es_rou=  0.06*p_c    # kW/GB*g/kW=g/GB

    # energy required for production, three parts: servers, clients, routers

    ep_ser=
    ep_cli=
    ep_rou=

    lifetime1=
    lifetime2=
    lifetime3=

    # total energy consumption is the sum of the above two parts.


    E1=es_ser+es_cli+es_rou
    E2=ep_ser/lifetime1+ep_cli/lifetime2+ep_rou/lifetime3

    E=E1+E2


    return E
# Out:
#   File "<ipython-input-17-0c2ce193e17d>", line 39
#     ep_ser=
#            ^
# SyntaxError: invalid syntax

# %%
def function2():  # chat

    p1=np.array([820,702,490,12,24,230,11,12,48,38,27])   #g Co2/kW
    p2=np.array([0.38106531, 0.03041596, 0.23030303, 0.10231508, 0.1582157 ,
           0.02394128, 0.04509693, 0.00252212, 0.02228496, 0.00338792,
           0.00045172])
    p_c=np.sum(p1*p2)


    #client - Desktop

    p_notebook= 30 # W
    #client - Desktop
    p_desktop=150 #W
    
    # phone
    p_mobile=10 # W

    # home network  bandwidth

    b_net=0.5 # GB/hour

    #total_gCO2e = data_utilsation*(data_centre_electricity usage +transmission_electricity usage)*gCO2e_for_electricity_generation

    # electricity consumption during operation , three parts:servers, clients, routers, per hour

    es_ser=  0.01*p_c     #  kW/GB*g/kW=g/GB
    es_cli=  p_desktop*1/1000/(b_net)*p_c        #kW/h*1hour/GB in one hour * g/GB =g/GB
    es_rou=  0.06*p_c    # kW/GB*g/kW=g/GB

    # energy required for production, three parts: servers, clients, routers

    ep_ser=
    ep_cli=
    ep_rou=

    lifetime1=
    lifetime2=
    lifetime3=

    # total energy consumption is the sum of the above two parts.


    E1=es_ser+es_cli+es_rou
    E2=ep_ser/lifetime1+ep_cli/lifetime2+ep_rou/lifetime3

    E=E1+E2


    return E

# %%
def function3(): # web

    p1=np.array([820,702,490,12,24,230,11,12,48,38,27])   #g Co2/kW
    p2=np.array([0.38106531, 0.03041596, 0.23030303, 0.10231508, 0.1582157 ,
           0.02394128, 0.04509693, 0.00252212, 0.02228496, 0.00338792,
           0.00045172])
    p_c=np.sum(p1*p2)


    #client - Desktop

    p_notebook= 30 # W
    #client - Desktop
    p_desktop=150 #W
    
    # phone
    p_mobile=10 # W

    # home network  bandwidth

    b_net=0.4 # GB/hour

    #total_gCO2e = data_utilsation*(data_centre_electricity usage +transmission_electricity usage)*gCO2e_for_electricity_generation

    # electricity consumption during operation , three parts:servers, clients, routers, per hour

    es_ser=  0.01*p_c     #  kW/GB*g/kW=g/GB
    es_cli=  p_desktop*1/1000/(b_net)*p_c        #kW/h*1hour/GB in one hour * g/GB =g/GB
    es_rou=  0.06*p_c    # kW/GB*g/kW=g/GB

    # energy required for production, three parts: servers, clients, routers

    ep_ser=
    ep_cli=
    ep_rou=

    lifetime1=
    lifetime2=
    lifetime3=

    # total energy consumption is the sum of the above two parts.


    E1=es_ser+es_cli+es_rou
    E2=ep_ser/lifetime1+ep_cli/lifetime2+ep_rou/lifetime3

    E=E1+E2


    return E

# %%
def function4(): #game

    p1=np.array([820,702,490,12,24,230,11,12,48,38,27])   #g Co2/kW
    p2=np.array([0.38106531, 0.03041596, 0.23030303, 0.10231508, 0.1582157 ,
           0.02394128, 0.04509693, 0.00252212, 0.02228496, 0.00338792,
           0.00045172])
    p_c=np.sum(p1*p2)


    #client - Desktop

    p_notebook= 30 # W
    #client - Desktop
    p_desktop=500 #W
    
    # phone
    p_mobile=10 # W

    # home network  bandwidth

    b_net=0.3 # GB/hour

    #total_gCO2e = data_utilsation*(data_centre_electricity usage +transmission_electricity usage)*gCO2e_for_electricity_generation

    # electricity consumption during operation , three parts:servers, clients, routers, per hour

    es_ser=  0.01*p_c     #  kW/GB*g/kW=g/GB
    es_cli=  p_desktop*1/1000/(b_net)*p_c        #kW/h*1hour/GB in one hour * g/GB =g/GB
    es_rou=  0.06*p_c    # kW/GB*g/kW=g/GB

    # energy required for production, three parts: servers, clients, routers

    ep_ser=
    ep_cli=
    ep_rou=

    lifetime1=
    lifetime2=
    lifetime3=

    # total energy consumption is the sum of the above two parts.


    E1=es_ser+es_cli+es_rou
    E2=ep_ser/lifetime1+ep_cli/lifetime2+ep_rou/lifetime3

    E=E1+E2


    return E
